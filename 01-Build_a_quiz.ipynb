# %% [markdown]
# Now, we would like to tackle a last problem : we want to allow only 3 wrong answers (among all questions).
#
# 7. Improve your code : if the user makes 3 wrong answers, the program should stop and print ("Too bad, you lost the game !")

# %%
print("Welcome to our quizz!\nYou have 3 lives.") 
#tips
# question answered
#white
#yes
#no

bad_answer = True
live = 3
while bad_answer :
    if live <=0:
        print("Oh no, you lost the quiz...")
        break
    question1 = input(" What is the color of the henrie IV white horse ?" )
    if question1 != "white" :
        live = live -1
        print("Question 1\nYour Answer : {}\nSorry, you have {} chances left".format(question1,live))
        bad_answer = True         
    else:
        print("Good job! This is the right answer")
        bad_answer = False
        question2 = input(" If the color pink is start written by a 'P', normally is start written by a 'N' isn't it ? " )
        if question2 != "yes":
            live = live -1
            print("Question 2\nYour Answer : {}\nSorry, you have {} chances left".format(question2,live))
            bad_answer = True
        else:
            print("Good job! This is the right answer")
            bad_answer = False
            question3 = input(" The first body trowed true the space, was a humain body or not ?" )
            if question3 != "no":
                live = live -1
                print("Question 3\nYour Answer : {}\nSorry, you have {} chances left".format(question3,live))
                bad_answer = True
            else:
                print("Good job! This is the right answer\nWell done! You are the quiz winner!")
                bad_answer = False
# Out:
# Welcome to our quizz!
# You have 3 lives.
# Question 1
# Your Answer : red
# Sorry, you have 2 chances left
# Good job! This is the right answer
# Good job! This is the right answer
# Question 3
# Your Answer : not
# Sorry, you have 1 chances left
# Good job! This is the right answer
# Good job! This is the right answer
# Good job! This is the right answer
# Well done! You are the quiz winner!
